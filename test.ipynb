# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
import yfinance as yf

# %%
from niftystockslist import niftylist

# %%
list = niftylist('Nifty500')
list[:] = [word.strip() + ".NS" for word in list]

# %%
data = yf.download(list, start="2022-03-01", end="2022-03-20", interval= '15m')
# Out:
# [*********************100%***********************]  501 of 501 completed
#
# 2 Failed downloads:
# - BURGERKING.NS: No data found for this date range, symbol may be delisted
# - PHILIPCARB.NS: No data found, symbol may be delisted

# %%
data['Close']
# Out:
#                              3MINDIA.NS  AARTIDRUGS.NS  AARTIIND.NS  \
# Datetime
# 2022-03-02 09:15:00+05:30  21320.000000     461.700012   922.950012
# 2022-03-02 09:30:00+05:30  21248.400391     458.000000   920.650024
# 2022-03-02 09:45:00+05:30  21152.349609     458.200012   917.849976
# 2022-03-02 10:00:00+05:30  21160.050781     458.250000   918.900024
# 2022-03-02 10:15:00+05:30  21160.000000     457.899994   916.599976
# ...                                 ...            ...          ...
# 2022-03-17 14:30:00+05:30  20139.900391     457.350006   895.900024
# 2022-03-17 14:45:00+05:30  20165.449219     456.000000   895.200012
# 2022-03-17 15:00:00+05:30  20137.099609     455.350006   890.500000
# 2022-03-17 15:15:00+05:30  19984.250000     455.649994   892.000000
# 2022-03-17 15:30:00+05:30           NaN     454.850006   891.599976
#
#                               AAVAS.NS       ABB.NS  ABBOTINDIA.NS  \
# Datetime
# ...
